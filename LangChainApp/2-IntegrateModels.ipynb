# %% [markdown]
# ### MODEL INTEGRATION WITH GEMINI, GPT, AND GROQ MODELS

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model='google_genai:gemini-2.5-flash')
response = model.invoke("why is india hot")
print(response.content)

groq_model = init_chat_model(model='groq:llama-3.1-8b-instant')
response1 = groq_model.invoke("how are himalayas formed")
print(response1.content)
# Out:
# The Himalayas, the world's highest mountain range, were formed as a result of the collision between the Indian tectonic plate and the Eurasian tectonic plate. This process is known as continental collision and it occurred about 50 million years ago. Here's a simplified explanation of how the Himalayas were formed:
#
# **Pre-Collision Stage:**
#
# * The Indian subcontinent, which was once a separate landmass, began to move northwards towards the Eurasian plate.
# * The Indian plate was moving at a rate of about 6-8 cm per year, which is much faster than the Eurasian plate.
# * As the Indian plate approached the Eurasian plate, the Earth's crust began to deform and buckle.
#
# **Continental Collision:**
#
# * Around 50 million years ago, the Indian plate collided with the Eurasian plate in a process known as continental collision.
# * The collision caused the Earth's crust to buckle and fold, resulting in the formation of the Himalayan mountain range.
# ...
