# %% [markdown]
# ### Trying out differnt tools and their Integration

# %%
import os
from dotenv import load_dotenv
from langchain.tools import tool
from langchain_groq import ChatGroq
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model_groq = ChatGroq(model="llama-3.1-8b-instant")

@tool
def findWeather(city:str) -> str:
    """Get a weather of the city"""
    return f"It is hot in {city} today"

model_with_tools = model_groq.bind_tools([findWeather])
response = model_with_tools.invoke("how is weather like in Hyderabad!")


###Tool Execution Loop
messages = [{"role":"user","content":"what the weather like in Hyderabad"}]
ai_msg = model_with_tools.invoke(messages)
messages.append(ai_msg)

for tool_call in ai_msg.tool_calls:
    tool_result = findWeather.invoke(tool_call)
    messages.append(tool_result)

final_response = model_with_tools.invoke(messages)
final_response
# Out:
# AIMessage(content='However, I need more information to provide the exact temperature.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 249, 'total_tokens': 262, 'completion_time': 0.030272753, 'completion_tokens_details': None, 'prompt_time': 0.026482, 'prompt_tokens_details': None, 'queue_time': 0.052368079, 'total_time': 0.056754753}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019dd3d1-2341-7001-bfc5-ac846216d839-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 249, 'output_tokens': 13, 'total_tokens': 262})
